# %% [markdown]
# # Get Taxonomy DBs, and associate with function counts by md5
#  by merge with KO - md5 count data

# %%
import requests  # to make the GET request 
import json  # to parse the JSON response to a Python dictionary
import csv  # to write our data to a CSV
import pandas as pd # to see our CSV
import numpy as np
import itertools
import re
import string

# %% [markdown]
# ## Get MG RAST m5nr taxonomy DB
# Below is converted to raw to avoid redownloading DB, open from file after.
# Broken into sections as steps are slow to repeat if error

# %% [raw]
# ###############################
# ### API call
# TaxDB = "http://api.metagenomics.anl.gov/m5nr/taxonomy?min_level=species"
#
# # API get KO data in JSON fmt, extract data
# response = requests.get(TaxDB)
# response_text = response.text
# data = json.loads(response_text)

# %% [raw]
# # Get data from 1st nested JSON layer
# # data['data']                      # 1st layer
# Taxa=data['data']                   # get 2nd layer       # Taxa

# %% [raw]
# # Make Dataframe, reorder columns
# m5nr_Taxonomy=pd.DataFrame(Taxa)
# m5nr_Taxonomy = m5nr_Taxonomy[['ncbi_tax_id','domain','phylum','class','order', 'family', 'genus', 'species','organism']]
# m5nr_Taxonomy.head()

# %% [raw]
# # Export table
# m5nr_Taxonomy.to_csv("MG_RAST_m5nr_Taxonomy_ncbiIDs_ranks", sep='\t', index=False)

# %% [markdown]
# ## Reimport Taxonomy table

# %%
# Reimport Taxonomy table from file
m5nr_Taxonomy = pd.read_csv("MG_RAST_m5nr_Taxonomy_ncbiIDs_ranks", sep ='\t' )   # m5nr_Taxonomy.head()

# Clean taxonomy by removing tax_id = 0, not useful for IDing otherwise          # m5nr_Taxonomy.shape
m5nr_TaxonomyCl = m5nr_Taxonomy[m5nr_Taxonomy.ncbi_tax_id !=0]                   # m5nr_TaxonomyCl.shape
m5nr_TaxonomyCl.head()
# Out:
#    ncbi_tax_id     domain                               phylum  \
# 0    1128364.0  Eukaryota                         Streptophyta
# 1    1252311.0  Eukaryota                           Arthropoda
# 2     179380.0  Eukaryota                           Arthropoda
# 3    1239215.0    Viruses  unclassified (derived from Viruses)
# 4     287018.0    Viruses  unclassified (derived from Viruses)
#
#                                  class                                order  \
# 0                           Liliopsida                         Zingiberales
# 1                              Insecta                          Hymenoptera
# 2                              Insecta                          Hymenoptera
# 3  unclassified (derived from Viruses)  unclassified (derived from Viruses)
# 4  unclassified (derived from Viruses)                       Picornavirales
#
#            family                                      genus  \
# 0     Marantaceae                                   Calathea
# 1   Ichneumonidae  unclassified (derived from Ichneumonidae)
# 2       Agaonidae                            Apocryptophagus
# 3   Caliciviridae                                  Norovirus
# 4  Picornaviridae                                Enterovirus
#
#                             species                          organism
# 0                Calathea hagbergii                Calathea hagbergii
# 1    Campopleginae sp. BOLD:AAM6952    Campopleginae sp. BOLD:AAM6952
# 2           Apocryptophagus sp. B73           Apocryptophagus sp. B73
# 3                     Norwalk virus      Norovirus FE128/15-04-10/TUN
# 4  Human rhinovirus 263 Berlin 2004  Human rhinovirus 263 Berlin 2004

# %% [markdown]
# ## Function: Get taxonomy IDs for each md5 from  MG RAST API

# %% [markdown]
# List md5s queried one ID at a time, then concatentated. Although entire list can be queried by API directly,
# API returns only 10 lines at a time, including multiple hits / md5 which can overruns the limit of 10 lines
# This prevents successful list chunking by 10 IDs at a time.

# %%
def md5_get_ncbi(test_list, source):

    list_=[]             # make empty DF to start          # (use dummy below ???)

    for i in test_list:
        payload = '{"source":"' + source + '","data":["' + i + '"]}'                           # Paste data (md5) into payload         # payload
        API_return = requests.post('http://api.metagenomics.anl.gov/m5nr/md5', data=payload)   # API call for payload
        out = API_return.json()                                                                # get json formatted data 
        md5_2tax = out['data']                                                                 # get first data layer 
        md5_2tax2 = pd.DataFrame(md5_2tax)                                                     # Make data frame
    
        columns = ['md5','ncbi_tax_id',"organism"]                                             # define columns of interest
        index = [0]                                                                            # one blank row
    
        # Test df is empty, if so make dummy 
        if md5_2tax2.empty:
            Fail = pd.DataFrame(index=index, columns=columns)                                  # Make empty DF                   
            Fail.iloc[0,0] = i                                                                 # Write md5 to first cell
            Fail.iloc[0,1] =0                                                                  # Write 0 to tax ID
            md5_2tax4 = Fail.iloc[0,:]                                                         # Get first row (match below)
    
        # or cut down to cols of interest
        else:
            md5_2tax3 = md5_2tax2[columns]                                                     # Reduce DF cols
            md5_2tax4 = md5_2tax3.iloc[0,:]                                                    # only get first row (except?)

        listn=list_.append(md5_2tax4)                                                         # append list of DFs     #list_3

    # Concatenate list of dfs, transpose for output
    Out = pd.concat(list_, axis=1, ignore_index=True)
    OutT = Out.T
    return OutT

# %% [markdown]
# ## Import KO- md5 sample count data from file

# %%
# read list of file IDs, mgID and SPID (use later)
KO_md5samples = pd.read_csv("MG_RAST_md5_WIDE_sample_count_KO_DB_133.txt", sep ='\t' )
KO_md5samples.head()
#KO_md5samples.shape
# Out:
#                                 MD5      KO  Browns_ThreeSqA_D1  \
# 0  00001508eba3f78863a4f9cb2463810d  K00566                 4.0
# 1  00001a757949ba4df5f1a9f8f6ba6c09  K01687                 2.0
# 2  00001aba8aee0c90a80969ea8da059f8  K03688                28.0
# 3  00002ee0efb6f4ef77f1a53bbeb207d0  K02013                 2.0
# 4  00003a8575ab2461c908a808ffe2002a  K00066                33.0
#
#    Browns_ThreeSqA_D2  Browns_ThreeSqB_D1  Browns_ThreeSqB_D2  \
# 0                 1.0                 3.0                 2.0
# 1                 4.0                 0.0                 3.0
# 2                13.0                16.0                 6.0
# 3                 1.0                 8.0                 3.0
# 4                31.0                39.0                22.0
#
#    Browns_ThreeSqC_D1  Browns_ThreeSqC_D2  Browns_TuleA_D1  Browns_TuleA_D2  \
# 0                 3.0                 1.0              0.0              0.0
# 1                 3.0                 2.0              0.0              1.0
# 2                19.0                 7.0             11.0             19.0
# 3                 4.0                 2.0              3.0              4.0
# 4                43.0                28.0             30.0             29.0
#
#          ...          WestPond_TuleC_D1  WestPond_TuleC_D2  White_CordA_D2  \
# 0        ...                        3.0                2.0             0.0
# 1        ...                        3.0                5.0            10.0
# 2        ...                       14.0                4.0            21.0
# 3        ...                        6.0                3.0             1.0
# 4        ...                       28.0               15.0            19.0
#
#    White_CordB_D2  White_ThreeSqA_D1  White_ThreeSqA_D2  White_ThreeSqB_D1  \
# 0             1.0                1.0                1.0                2.0
# 1             9.0                1.0                1.0                3.0
# 2            34.0               12.0               19.0                5.0
# 3             3.0                1.0                2.0                2.0
# 4            15.0               27.0               33.0               24.0
#
#    White_ThreeSqB_D2  White_ThreeSqC_D1  White_ThreeSqC_D2
# 0                1.0                0.0                1.0
# 1                6.0                1.0                1.0
# 2               36.0               54.0               22.0
# 3                3.0                1.0                2.0
# 4               18.0               14.0               33.0
#
# [5 rows x 135 columns]

# %% [markdown]
# ## Import KO functions of interest table, ontology

# %%
# read list of file IDs, mgID and SPID (use later)
# NOTE THIS VERSION ONLY HAS NPSch4, but updated mcrA2
KO_CNPsCH4_DB = pd.read_csv("CNPSch4_KOs_whh12_17.txt", sep ='\t' )                      # KO_CNPsCH4_DB.head()

# Full ontology here
#KO_CNPsCH4_DB = pd.read_csv("Ontology_KO_CNPSch4_Fm_whh_12.17v0.txt", sep ='\t' )        # KO_CNPsCH4_DB.head()
#KO_CNPsCH4_DB_cl = KO_CNPsCH4_DB[['Index', 'L1', 'L2', 'KO','gene','fxn','EC']]
#KO_CNPsCH4_DB_cl

# %%
# No subset!!  Using NPSch4 functions
KO_subset = KO_CNPsCH4_DB

# Get vector of KOs of interest
#KOs_CNPsCH4 = pd.DataFrame(KO_CNPsCH4_DB['KO'])
#KOs_CNPsCH4.head()

# Note too many md5s to run fast enough, chunk them out by function
## ABSTRACTION FOR Below future function  # or KO_subset = KO_CH4_ox
#KO_subset0 = KO_CNPsCH4_DB_cl[KO_CNPsCH4_DB_cl.L1!="Fermentation"]
#KO_subset = KO_subset0[KO_subset0.L1 != ""]
# KO_subset = KO_CNPsCH4_DB[KO_CNPsCH4_DB.L1=="CH4_cycling"]
# KO_subset = KO_CNPsCH4_DB[KO_CNPsCH4_DB.L2=="CH4_oxidation"]
# KO_subset

# %% [markdown]
# ## Get md5s corresponding to KOs of interest

# %%
# Get md5 list from KOs, merge
md5_KO_rast133 = KO_md5samples[['MD5', 'KO']]                                   # Get only MD5 & KO combinations  # md5_KO_rast133.head()       # md5_KO_rast133.shape
KO_subset_md5 = pd.merge(KO_subset, md5_KO_rast133, on = "KO", how='inner')     # Merge with KO subset            #  merge INNER needed for no-count KOs  #KO_subset_md5 # .head()   # KO_subset_md5.shape  #-- only 13 for CH4 oxidatio
subset_md5 = pd.DataFrame(KO_subset_md5['MD5'])                                 # Get only KO subset md5s         # subset_md5# .head()
subset_md5u = subset_md5.drop_duplicates(keep='first')                          # get unique md5s                 # subset_md5u# .head()      # CNPsCH4_md5u.shape 
subset_md5_list = subset_md5u['MD5'].tolist()                                   # make md5 list for API query # get list  
len(subset_md5_list)
#KO_subset_md5
# Out:
# 31462

# %% [markdown]
# ### Limit List size

# %%
# Get test list -- no LIMIT !!!
test_list = subset_md5_list # [0:5000]                    # Make test subset of list       # len(test_list)
test_listU = set(test_list)                               # get unique values from list    # len(test_listu)

md5_list_paste = '", "'.join(test_listU)                  # send list to string, adding middle quotes
md5_list_paste = md5_list_paste.replace('\r', '')         # replace returns with "" for flat string       # md5_list_paste

# %% [markdown]
# ## API query for md5 - taxID mappping

# %%
# Get RefSeq data
# Insert md5 LIST data into API payload string 
payload = '{"source":"RefSeq","limit":500000,"data":["' + md5_list_paste + '"]}'                  # Paste data (md5) into payload         #payload

# API Call with md5 payload given above
API_return = requests.post('http://api.metagenomics.anl.gov/m5nr/md5', data=payload)   # API call for payload
out = API_return.json()                                                                # get json formatted data 
md5_2tax = out['data']                                                                 # get first data layer 
md5_2taxd = pd.DataFrame(md5_2tax)                                                     # make DF
# md5_2tax2

columns = ['md5','ncbi_tax_id',"organism"]                                             # get columns to cut   
md5_2taxdr = md5_2taxd[columns]                                                        # cut by columns   # md5_2taxdr.head()

# There are many duplicated md5 IDs...looks like each is just different strain, not important for Taxonomy
#  md5_2taxdrDups = md5_2taxdr[md5_2taxdr.duplicated('md5', keep = False)]                               # md5_2taxdrDups.head()  # md5_2taxdrDups.shape  # md5_2taxdrDups
md5u_2taxdr = md5_2taxdr.drop_duplicates('md5', keep='first')                                            # md5u_2taxdr  # md5u_2taxdr.shape

# %%
# md5u_2taxdr  # 
#md5u_2taxdr.shape

# %% [raw]
# #Get Refseq TaxID fails
# md5_GB_taxF = md5_2taxdr[md5_2taxdr.ncbi_tax_id == 0]   # taxID failure rows
# md5_GB_taxFl = md5_GB_taxF['md5'].tolist()              # List of md5 fails      # md5_GB_taxFl
# md5_GB_taxF

# %% [raw]
# ###  3) Send failures to KEGG lookup:                   # Test-- KEGG works. Failed test for missing: GenBank, Interpro, KBASE
# Redo = md5_get_ncbi(md5_GB_taxFl, "KEGG")                                            # Redo.head()
#
# ## Join RefSeq and KEGG
# md5_GB_taxG2 = md5u_2taxdr.append(Redo, ignore_index=True)
# md5_GB_taxG2

# %% [markdown]
# ### Test merge with full Taxnomy

# %% [raw]
# # Clean taxonomy by removing tax_id = 0                               # m5nr_Taxonomy.shape
# m5nr_TaxonomyCl = m5nr_Taxonomy[m5nr_Taxonomy.ncbi_tax_id !=0]        # m5nr_TaxonomyCl.shape

# %%
# Set abstraction variable for md5 output from API
md5_GB = md5_2taxdr #.head(5)

## MERGE md5 IDs with Full Taxonomy
md5_GB_tax = pd.merge(md5_GB, m5nr_TaxonomyCl, how = 'left', on="ncbi_tax_id")

# Drop exact duplicates 
md5_GB_tax0 = md5_GB_tax.iloc[:,:-1]                       # Drop strain info assoc. with Taxonomy DB given by organism_y 
md5_GB_taxU = md5_GB_tax0.drop_duplicates(keep='first')    # Drop duplicates, get unique  
#md5_GB_taxU# .head() md5_GB_taxU.shape

# %%
# There are many duplicated md5 IDs...looks like each is just different strain, not important for Taxonomy
# md5d_GB_taxU = md5_GB_taxU[md5_GB_taxU.duplicated('md5', keep = False)]                                     # md5d_GB_taxU 
md5u_GB_taxU = md5_GB_taxU.drop_duplicates('md5', keep='first')                  # drop md5 strain duplicates                                     
# md5u_GB_taxU
# md5u_2taxdr  # md5u_2taxdr.shape

# %%
md5u_GB_taxU.shape # -- A few extras, hmmm...
# Send back taxiD = 0 for alt. lookup...
# possible ambig calls-- send to other DB?

#POST MERGE, should remove any human / mouse / fly hits (by domain???)
# Out:
# (31223, 10)

# %% [markdown]
# ## merge md5 taxonomy with KO hierarchy

# %%
# Get KO-md5 mapping for KO subset
# note if running with full Ontology the columns are diff : ['Index', 'L1', 'L2','KO','gene', 'fxn', 'EC', 'MD5']  # Clean columns # KO_subset_md5_cl


KO_subset_md5 = pd.merge(KO_subset, md5_KO_rast133, on="KO", how='inner')                       # KO_subset_md5
KO_subset_md5_cl = KO_subset_md5[['L1', 'L3','KO','gene', 'function', 'EC', 'MD5']]   # Clean columns # KO_subset_md5_cl

#KO_subset_md5_cl.rename(columns={'MD5':'md5'}, inplace=True)
KO_subset_md5_cl.columns = ['L1', 'L3','KO','gene', 'function', 'EC', 'md5']   # Clean columns # KO_subset_md5_cl  #KO_subset_md5_cl
KO_subset_md5_clU = KO_subset_md5_cl.drop_duplicates(keep='first')                 # Drop duplicates, get unique  
KO_subset_md5_clU.shape
#KO_subset_md5_cl
# Out:
# (32655, 7)

# %%
# Merge with Taxonomy
#KO_subset_md5Tax = pd.merge(KO_subset_md5_cl, md5u_GB_taxU, left_on=['md5','KO'], right_on=['md5','KO'], how='inner')
KO_subset_md5Tax = pd.merge(KO_subset_md5_cl, md5u_GB_taxU, on="md5", how='inner')
# KO_subset_md5Tax = pd.merge(KO_subset_md5_cl, md5_GB_taxU, on="md5", how='inner')
#KO_subset_md5Tax.rename(columns={'md5':'MD5'}, inplace=True)                        # convert to "MD5" again
KO_subset_md5Tax#.shape
# Out:
#                 L1         L3      KO  gene  \
# 0         Nitrogen      N_DNT  K00368  nirK
# 1         Nitrogen      N_DNT  K00368  nirK
# 2         Nitrogen      N_DNT  K00368  nirK
# 3         Nitrogen      N_DNT  K00368  nirK
# 4         Nitrogen      N_DNT  K00368  nirK
# 5         Nitrogen      N_DNT  K00368  nirK
# 6         Nitrogen      N_DNT  K00368  nirK
# 7         Nitrogen      N_DNT  K00368  nirK
# 8         Nitrogen      N_DNT  K00368  nirK
# 9         Nitrogen      N_DNT  K00368  nirK
# 10        Nitrogen      N_DNT  K00368  nirK
# 11        Nitrogen      N_DNT  K00368  nirK
# 12        Nitrogen      N_DNT  K00368  nirK
# 13        Nitrogen      N_DNT  K00368  nirK
# 14        Nitrogen      N_DNT  K00368  nirK
# 15        Nitrogen      N_DNT  K00368  nirK
# 16        Nitrogen      N_DNT  K00368  nirK
# 17        Nitrogen      N_DNT  K00368  nirK
# 18        Nitrogen      N_DNT  K00368  nirK
# 19        Nitrogen      N_DNT  K00368  nirK
# 20        Nitrogen      N_DNT  K00368  nirK
# 21        Nitrogen      N_DNT  K00368  nirK
# 22        Nitrogen      N_DNT  K00368  nirK
# 23        Nitrogen      N_DNT  K00368  nirK
# 24        Nitrogen      N_DNT  K00368  nirK
# 25        Nitrogen      N_DNT  K00368  nirK
# 26        Nitrogen      N_DNT  K00368  nirK
# 27        Nitrogen      N_DNT  K00368  nirK
# 28        Nitrogen      N_DNT  K00368  nirK
# 29        Nitrogen      N_DNT  K00368  nirK
# ...            ...        ...     ...   ...
# 32378  CH4_cycling  CH4_Archa  K03390  hdrC
# 32379  CH4_cycling  CH4_Archa  K03390  hdrC
# 32380  CH4_cycling  CH4_Archa  K03390  hdrC
# 32381  CH4_cycling  CH4_Archa  K03390  hdrC
# 32382  CH4_cycling  CH4_Archa  K03390  hdrC
# 32383  CH4_cycling  CH4_Archa  K03390  hdrC
# 32384  CH4_cycling  CH4_Archa  K03390  hdrC
# 32385  CH4_cycling  CH4_Archa  K03390  hdrC
# 32386  CH4_cycling  CH4_Archa  K03390  hdrC
# 32387  CH4_cycling  CH4_Archa  K03390  hdrC
# 32388  CH4_cycling  CH4_Archa  K03390  hdrC
# 32389  CH4_cycling  CH4_Archa  K03390  hdrC
# 32390  CH4_cycling  CH4_Archa  K03390  hdrC
# 32391  CH4_cycling  CH4_Archa  K03390  hdrC
# 32392  CH4_cycling  CH4_Archa  K03390  hdrC
# 32393  CH4_cycling  CH4_Archa  K03390  hdrC
# 32394  CH4_cycling  CH4_Archa  K03390  hdrC
# 32395  CH4_cycling  CH4_Archa  K03390  hdrC
# 32396  CH4_cycling  CH4_Archa  K03390  hdrC
# 32397  CH4_cycling  CH4_Archa  K03390  hdrC
# 32398  CH4_cycling  CH4_Archa  K03390  hdrC
# 32399  CH4_cycling  CH4_Archa  K03390  hdrC
# 32400  CH4_cycling  CH4_Archa  K03390  hdrC
# 32401  CH4_cycling  CH4_Archa  K03390  hdrC
# 32402  CH4_cycling  CH4_Archa  K03390  hdrC
# 32403  CH4_cycling  CH4_Archa  K03390  hdrC
# 32404  CH4_cycling  CH4_Archa  K03390  hdrC
# 32405  CH4_cycling  CH4_Archa  K03390  hdrC
# 32406  CH4_cycling  CH4_Archa  K03390  hdrC
# 32407  CH4_cycling  CH4_Archa  K03390  hdrC
#
#                                   function             EC  \
# 0           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 1           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 2           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 3           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 4           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 5           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 6           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 7           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 8           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 9           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 10          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 11          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 12          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 13          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 14          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 15          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 16          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 17          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 18          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 19          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 20          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 21          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 22          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 23          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 24          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 25          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 26          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 27          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 28          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 29          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# ...                                    ...            ...
# 32378  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32379  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32380  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32381  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32382  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32383  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32384  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32385  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32386  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32387  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32388  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32389  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32390  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32391  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32392  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32393  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32394  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32395  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32396  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32397  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32398  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32399  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32400  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32401  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32402  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32403  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32404  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32405  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32406  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32407  heterodisulfide reductase subunit C  [EC:1.8.98.1]
#
#                                     md5  ncbi_tax_id  \
# 0      00f21a1f7b33ec7e1862ac168bae479d     412021.0
# 1      090a06e6f790f4175d55a94ef0af0565     375451.0
# 2      094c7dee12562cd34d6dfac9e8627306     583345.0
# 3      0a66c0f71baf62f146da7450750ffae1     318161.0
# 4      0a877b9f940692206489cc8d5f25175c     485914.0
# 5      128dc50e0803e13f47f5a84b401a1c67     416269.0
# 6      13a67f6021ca34f30fb5cb4686a5bf3b    1169230.0
# 7      13fb139a0ace3097c1bf60169ab995f5     456481.0
# 8      14178c32b846869981e50acb42770e5a     439375.0
# 32405  f7a0f8c043c57a37217e59619613e6dd     246194.0
# 32406  ff393ab91e4d3f27dfaffa05ca00bfee     269797.0
# 32407  ff8af2d21267078a0ba8849cb2d02998      65393.0
#
#                                               organism_x    domain  \
# 0                         Burkholderia mallei ATCC 10399  Bacteria
# 1                      Roseobacter denitrificans OCh 114  Bacteria
# 2                             Methylotenera mobilis JLW8  Bacteria
# 3                         Shewanella denitrificans OS217  Bacteria
# 4                     Halomicrobium mukohataei DSM 12286   Archaea
# 5      Actinobacillus pleuropneumoniae serovar 5b str...  Bacteria
# 6                                    Brucella ovis 63/96  Bacteria
# 7      Leptospira biflexa serovar Patoc strain 'Patoc...  Bacteria
# 8                       Ochrobactrum anthropi ATCC 49188  Bacteria
# 9                      Haloarcula marismortui ATCC 43049   Archaea
# 10     Actinobacillus pleuropneumoniae serovar 3 str....  Bacteria
# 11                         Colwellia psychrerythraea 34H  Bacteria
# 12                        Ralstonia solanacearum GMI1000  Bacteria
# 13                  Micromonospora aurantiaca ATCC 27029  Bacteria
# 14                           Aromatoleum aromaticum EbN1  Bacteria
# 15                        Burkholderia mallei 2002721280  Bacteria
# 16                                Haloferax volcanii DS2   Archaea
# 17                               Geobacillus sp. Y4.1MC1  Bacteria
# 18                               Geobacillus sp. G11MC16  Bacteria
# 19                              Starkeya novella DSM 506  Bacteria
# 20                         Burkholderia pseudomallei 668  Bacteria
# 21                     Rhodopseudomonas palustris CGA009  Bacteria
# 22                      Bdellovibrio bacteriovorus HD100  Bacteria
# 23                     Herpetosiphon aurantiacus DSM 785  Bacteria
# 24                        Phenylobacterium zucineum HLK1  Bacteria
# 25                      Cellulomonas flavigena DSM 20109  Bacteria
# 26                      Chloroflexus aurantiacus J-10-fl  Bacteria
# 27                           Pseudomonas entomophila L48  Bacteria
# 28                        Neisseria lactamica ATCC 23970  Bacteria
# 29                           Methylocella silvestris BL2  Bacteria
# ...                                                  ...       ...
# 32378             Syntrophothermus lipocalidus DSM 12680  Bacteria
# 32379          Acidithiobacillus ferrooxidans ATCC 53993  Bacteria
# 32380            Hyphomicrobium denitrificans ATCC 51888  Bacteria
# 32381                 Methanosarcina barkeri str. Fusaro   Archaea
# 32382                               Geobacter lovleyi SZ  Bacteria
# 32383                      Methanocella paludicola SANAE   Archaea
# 32384                          Kyrpidia tusciae DSM 2912  Bacteria
# 32385                 Methanohalobium evestigatum Z-7303   Archaea
# 32386                       Methanocella arvoryzae MRE50   Archaea
# 32387                         Methanopyrus kandleri AV19   Archaea
# 32388  Desulfovibrio desulfuricans subsp. desulfurica...  Bacteria
# 32389                         Thioalkalivibrio sp. ALJ17  Bacteria
# 32390                              Thermincola potens JR  Bacteria
# 32391                               Aquifex aeolicus VF5  Bacteria
# 32392                  Heliobacterium modesticaldum Ice1  Bacteria
# 32393                    Thermomicrobium roseum DSM 5159  Bacteria
# 32394                     Ilyobacter polytropus DSM 2926  Bacteria
# 32395  Methanothermobacter thermautotrophicus str. De...   Archaea
# 32396                   Methanohalophilus mahii DSM 5219   Archaea
# 32400   Euryarchaeota                            Methanobacteria
# 32401  Actinobacteria                             Actinobacteria
# 32402   Euryarchaeota                               Archaeoglobi
# 32403  Proteobacteria                        Deltaproteobacteria
# 32404  Proteobacteria                         Betaproteobacteria
# 32405      Firmicutes                                 Clostridia
# 32406   Euryarchaeota                            Methanomicrobia
# 32407   Cyanobacteria  unclassified (derived from Cyanobacteria)
#
#                         order                                     family  \
# 0             Burkholderiales                           Burkholderiaceae
# 1             Rhodobacterales                           Rhodobacteraceae
# 2             Methylophilales                           Methylophilaceae
# 3             Alteromonadales                             Shewanellaceae
# 4             Halobacteriales                           Halobacteriaceae
# 5              Pasteurellales                            Pasteurellaceae
# 6                 Rhizobiales                               Brucellaceae
# 7              Spirochaetales                             Leptospiraceae
# 8                 Rhizobiales                               Brucellaceae
# 9             Halobacteriales                           Halobacteriaceae
# 10             Pasteurellales                            Pasteurellaceae
# 11            Alteromonadales                              Colwelliaceae
# 12            Burkholderiales                           Burkholderiaceae
# 13            Actinomycetales                         Micromonosporaceae
# 14              Rhodocyclales                             Rhodocyclaceae
# 15            Burkholderiales                           Burkholderiaceae
# 16            Halobacteriales                           Halobacteriaceae
# 17                 Bacillales                                Bacillaceae
# 18                 Bacillales                                Bacillaceae
# 19                Rhizobiales                          Xanthobacteraceae
# 20            Burkholderiales                           Burkholderiaceae
# 21                Rhizobiales                          Bradyrhizobiaceae
# 22          Bdellovibrionales                         Bdellovibrionaceae
# 23          Herpetosiphonales                         Herpetosiphonaceae
# 24            Caulobacterales                           Caulobacteraceae
# 25            Actinomycetales                          Cellulomonadaceae
# 26             Chloroflexales                            Chloroflexaceae
# 27            Pseudomonadales                           Pseudomonadaceae
# 28               Neisseriales                              Neisseriaceae
# 29                Rhizobiales                           Beijerinckiaceae
# ...                       ...                                        ...
# 32378           Clostridiales                        Syntrophomonadaceae
# 32379     Acidithiobacillales                       Acidithiobacillaceae
# 32380             Rhizobiales                          Hyphomicrobiaceae
# 32381       Methanosarcinales                         Methanosarcinaceae
# 32382      Desulfuromonadales                             Geobacteraceae
# 32383         Methanocellales                           Methanocellaceae
# 32384              Bacillales                        Alicyclobacillaceae
# 32385       Methanosarcinales                         Methanosarcinaceae
# 32386         Methanocellales                           Methanocellaceae
# 32387          Methanopyrales                            Methanopyraceae
# 32388      Desulfovibrionales                        Desulfovibrionaceae
# 32389            Chromatiales                     Ectothiorhodospiraceae
# 32390           Clostridiales                             Peptococcaceae
# 32391             Aquificales                               Aquificaceae
# 32392           Clostridiales                          Heliobacteriaceae
# 32393       Thermomicrobiales                         Thermomicrobiaceae
# 32394         Fusobacteriales                           Fusobacteriaceae
# 32395      Methanobacteriales                        Methanobacteriaceae
# 32396       Methanosarcinales                         Methanosarcinaceae
# 32397           Clostridiales                             Peptococcaceae
# 32398         Archaeoglobales                           Archaeoglobaceae
# 32399         Methanococcales                           Methanococcaceae
# 32400      Methanobacteriales                        Methanobacteriaceae
# 32401        Coriobacteriales                          Coriobacteriaceae
# 32402         Archaeoglobales                           Archaeoglobaceae
# 32403       Desulfobacterales                         Desulfobacteraceae
# 32404       Hydrogenophilales                         Hydrogenophilaceae
# 32405  Thermoanaerobacterales                    Thermoanaerobacteraceae
# 32406       Methanosarcinales                         Methanosarcinaceae
# 32407           Chroococcales  unclassified (derived from Chroococcales)
#
#                      genus                                 species
# 0             Burkholderia                     Burkholderia mallei
# 1              Roseobacter               Roseobacter denitrificans
# 2            Methylotenera                   Methylotenera mobilis
# 3               Shewanella                Shewanella denitrificans
# 4            Halomicrobium                Halomicrobium mukohataei
# 5           Actinobacillus         Actinobacillus pleuropneumoniae
# 6                 Brucella                           Brucella ovis
# 7               Leptospira                      Leptospira biflexa
# 8             Ochrobactrum                   Ochrobactrum anthropi
# 9               Haloarcula                  Haloarcula marismortui
# 10          Actinobacillus         Actinobacillus pleuropneumoniae
# 11               Colwellia               Colwellia psychrerythraea
# 12               Ralstonia                  Ralstonia solanacearum
# 13          Micromonospora               Micromonospora aurantiaca
# 14             Aromatoleum                  Aromatoleum aromaticum
# 15            Burkholderia                     Burkholderia mallei
# 16               Haloferax                      Haloferax volcanii
# 17             Geobacillus                 Geobacillus sp. Y4.1MC1
# 18             Geobacillus                 Geobacillus sp. G11MC16
# 19                Starkeya                        Starkeya novella
# 20            Burkholderia               Burkholderia pseudomallei
# 21        Rhodopseudomonas              Rhodopseudomonas palustris
# 22            Bdellovibrio              Bdellovibrio bacteriovorus
# 23           Herpetosiphon               Herpetosiphon aurantiacus
# 24        Phenylobacterium               Phenylobacterium zucineum
# 25            Cellulomonas                  Cellulomonas flavigena
# 26            Chloroflexus                Chloroflexus aurantiacus
# 27             Pseudomonas                 Pseudomonas entomophila
# 28               Neisseria                     Neisseria lactamica
# 29            Methylocella                 Methylocella silvestris
# ...                    ...                                     ...
# 32378     Syntrophothermus            Syntrophothermus lipocalidus
# 32379    Acidithiobacillus          Acidithiobacillus ferrooxidans
# 32380       Hyphomicrobium            Hyphomicrobium denitrificans
# 32381       Methanosarcina                  Methanosarcina barkeri
# 32382            Geobacter                       Geobacter lovleyi
# 32383         Methanocella                 Methanocella paludicola
# 32384             Kyrpidia                        Kyrpidia tusciae
# 32385      Methanohalobium             Methanohalobium evestigatum
# 32386         Methanocella                  Methanocella arvoryzae
# 32387         Methanopyrus                   Methanopyrus kandleri
# 32388        Desulfovibrio             Desulfovibrio desulfuricans
# 32389     Thioalkalivibrio              Thioalkalivibrio sp. ALJ17
# 32390          Thermincola                      Thermincola potens
# 32391              Aquifex                        Aquifex aeolicus
# 32392       Heliobacterium            Heliobacterium modesticaldum
# 32393      Thermomicrobium                  Thermomicrobium roseum
# 32394           Ilyobacter                   Ilyobacter polytropus
# 32395  Methanothermobacter  Methanothermobacter thermautotrophicus
# 32396    Methanohalophilus                 Methanohalophilus mahii
# 32397     Desulfotomaculum            Desulfotomaculum acetoxidans
# 32398        Archaeoglobus                  Archaeoglobus fulgidus
# 32399        Methanococcus                 Methanococcus vannielii
# 32400   Methanobrevibacter              Methanobrevibacter smithii
# 32401              Slackia              Slackia heliotrinireducens
# 32402        Archaeoglobus                 Archaeoglobus profundus
# 32403     Desulfobacterium          Desulfobacterium autotrophicum
# 32404         Thiobacillus              Thiobacillus denitrificans
# 32405     Carboxydothermus       Carboxydothermus hydrogenoformans
# 32406       Methanosarcina                  Methanosarcina barkeri
# 32407           Cyanothece                 Cyanothece sp. PCC 7424
#
# [32408 rows x 16 columns]

# %% [markdown]
# ## merge KO-md5 taxonomy with KO-md5 count data

# %%
# UGH, need to convert to cap MD5 again
KO_subset_md5Tax.rename(columns={'md5':'MD5'}, inplace=True)                                    #KO_subset_md5Tax

# MERGE KO-md5 Taxnomomy and counts                                                             #KO_md5samples # KO_md5samples.head()
KOsubset_md5Tax_counts133 = pd.merge(KO_subset_md5Tax,KO_md5samples, on='MD5', how='inner')
KOsubset_md5Tax_counts133 = pd.merge(KO_subset_md5Tax,KO_md5samples, left_on=['MD5','KO'], right_on=['MD5','KO'], how='inner')

# %%
cols = pd.DataFrame(KOsubset_md5Tax_counts133.columns)
#cols## TODO: DROP KO_y column

### note SITE ORDERING now alphabetical!

# %%
KOsubset_md5Tax_counts133#.head()
# Out:
#                 L1         L3      KO  gene  \
# 0         Nitrogen      N_DNT  K00368  nirK
# 1         Nitrogen      N_DNT  K00368  nirK
# 2         Nitrogen      N_DNT  K00368  nirK
# 3         Nitrogen      N_DNT  K00368  nirK
# 4         Nitrogen      N_DNT  K00368  nirK
# 5         Nitrogen      N_DNT  K00368  nirK
# 6         Nitrogen      N_DNT  K00368  nirK
# 7         Nitrogen      N_DNT  K00368  nirK
# 8         Nitrogen      N_DNT  K00368  nirK
# 9         Nitrogen      N_DNT  K00368  nirK
# 10        Nitrogen      N_DNT  K00368  nirK
# 11        Nitrogen      N_DNT  K00368  nirK
# 12        Nitrogen      N_DNT  K00368  nirK
# 13        Nitrogen      N_DNT  K00368  nirK
# 14        Nitrogen      N_DNT  K00368  nirK
# 15        Nitrogen      N_DNT  K00368  nirK
# 16        Nitrogen      N_DNT  K00368  nirK
# 17        Nitrogen      N_DNT  K00368  nirK
# 18        Nitrogen      N_DNT  K00368  nirK
# 19        Nitrogen      N_DNT  K00368  nirK
# 20        Nitrogen      N_DNT  K00368  nirK
# 21        Nitrogen      N_DNT  K00368  nirK
# 22        Nitrogen      N_DNT  K00368  nirK
# 23        Nitrogen      N_DNT  K00368  nirK
# 24        Nitrogen      N_DNT  K00368  nirK
# 25        Nitrogen      N_DNT  K00368  nirK
# 26        Nitrogen      N_DNT  K00368  nirK
# 27        Nitrogen      N_DNT  K00368  nirK
# 28        Nitrogen      N_DNT  K00368  nirK
# 29        Nitrogen      N_DNT  K00368  nirK
# ...            ...        ...     ...   ...
# 32378  CH4_cycling  CH4_Archa  K03390  hdrC
# 32379  CH4_cycling  CH4_Archa  K03390  hdrC
# 32380  CH4_cycling  CH4_Archa  K03390  hdrC
# 32381  CH4_cycling  CH4_Archa  K03390  hdrC
# 32382  CH4_cycling  CH4_Archa  K03390  hdrC
# 32383  CH4_cycling  CH4_Archa  K03390  hdrC
# 32384  CH4_cycling  CH4_Archa  K03390  hdrC
# 32385  CH4_cycling  CH4_Archa  K03390  hdrC
# 32386  CH4_cycling  CH4_Archa  K03390  hdrC
# 32387  CH4_cycling  CH4_Archa  K03390  hdrC
# 32388  CH4_cycling  CH4_Archa  K03390  hdrC
# 32389  CH4_cycling  CH4_Archa  K03390  hdrC
# 32390  CH4_cycling  CH4_Archa  K03390  hdrC
# 32391  CH4_cycling  CH4_Archa  K03390  hdrC
# 32392  CH4_cycling  CH4_Archa  K03390  hdrC
# 32393  CH4_cycling  CH4_Archa  K03390  hdrC
# 32394  CH4_cycling  CH4_Archa  K03390  hdrC
# 32395  CH4_cycling  CH4_Archa  K03390  hdrC
# 32396  CH4_cycling  CH4_Archa  K03390  hdrC
# 32397  CH4_cycling  CH4_Archa  K03390  hdrC
# 32398  CH4_cycling  CH4_Archa  K03390  hdrC
# 32399  CH4_cycling  CH4_Archa  K03390  hdrC
# 32400  CH4_cycling  CH4_Archa  K03390  hdrC
# 32401  CH4_cycling  CH4_Archa  K03390  hdrC
# 32402  CH4_cycling  CH4_Archa  K03390  hdrC
# 32403  CH4_cycling  CH4_Archa  K03390  hdrC
# 32404  CH4_cycling  CH4_Archa  K03390  hdrC
# 32405  CH4_cycling  CH4_Archa  K03390  hdrC
# 32406  CH4_cycling  CH4_Archa  K03390  hdrC
# 32407  CH4_cycling  CH4_Archa  K03390  hdrC
#
#                                   function             EC  \
# 0           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 1           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 2           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 3           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 4           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 5           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 6           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 7           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 8           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 9           nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 10          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 11          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 12          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 13          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 14          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 15          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 16          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 17          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 18          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 19          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 20          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 21          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 22          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 23          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 24          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 25          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 26          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 27          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 28          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# 29          nitrite reductase (NO-forming)   [EC:1.7.2.1]
# ...                                    ...            ...
# 32378  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32379  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32380  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32381  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32382  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32383  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32384  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32385  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32386  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32387  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32388  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32389  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32390  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32391  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32392  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32393  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32394  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32395  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32396  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32397  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32398  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32399  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32400  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32401  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32402  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32403  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32404  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32405  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32406  heterodisulfide reductase subunit C  [EC:1.8.98.1]
# 32407  heterodisulfide reductase subunit C  [EC:1.8.98.1]
#
#                                     MD5  ncbi_tax_id  \
# 0      00f21a1f7b33ec7e1862ac168bae479d     412021.0
# 1      090a06e6f790f4175d55a94ef0af0565     375451.0
# 2      094c7dee12562cd34d6dfac9e8627306     583345.0
# 3      0a66c0f71baf62f146da7450750ffae1     318161.0
# 4      0a877b9f940692206489cc8d5f25175c     485914.0
# 5      128dc50e0803e13f47f5a84b401a1c67     416269.0
# 6      13a67f6021ca34f30fb5cb4686a5bf3b    1169230.0
# 7      13fb139a0ace3097c1bf60169ab995f5     456481.0
# 8      14178c32b846869981e50acb42770e5a     439375.0
# 9      16841c9e1c07f851faab01e1ff3213fe     272569.0
# 10     16a09af1fd8d01739ba7b693c8caf01c     434271.0
# 11     18406d7d47bff478a0d0b57d3ab490ad     167879.0
# 12     1880cc1b23b62fcdb2b825bae1c2ab48     267608.0
# 13     1ba6dffd9d8133c09b165b771c5bb22e     644283.0
# 1                      Roseobacter denitrificans OCh 114  Bacteria
# 2                             Methylotenera mobilis JLW8  Bacteria
# 3                         Shewanella denitrificans OS217  Bacteria
# 4                     Halomicrobium mukohataei DSM 12286   Archaea
# 5      Actinobacillus pleuropneumoniae serovar 5b str...  Bacteria
# 6                                    Brucella ovis 63/96  Bacteria
# 7      Leptospira biflexa serovar Patoc strain 'Patoc...  Bacteria
# 8                       Ochrobactrum anthropi ATCC 49188  Bacteria
# 9                      Haloarcula marismortui ATCC 43049   Archaea
# 10     Actinobacillus pleuropneumoniae serovar 3 str....  Bacteria
# 11                         Colwellia psychrerythraea 34H  Bacteria
# 12                        Ralstonia solanacearum GMI1000  Bacteria
# 13                  Micromonospora aurantiaca ATCC 27029  Bacteria
# 14                           Aromatoleum aromaticum EbN1  Bacteria
# 15                        Burkholderia mallei 2002721280  Bacteria
# 16                                Haloferax volcanii DS2   Archaea
# 17                               Geobacillus sp. Y4.1MC1  Bacteria
# 18                               Geobacillus sp. G11MC16  Bacteria
# 19                              Starkeya novella DSM 506  Bacteria
# 20                         Burkholderia pseudomallei 668  Bacteria
# 21                     Rhodopseudomonas palustris CGA009  Bacteria
# 22                      Bdellovibrio bacteriovorus HD100  Bacteria
# 23                     Herpetosiphon aurantiacus DSM 785  Bacteria
# 24                        Phenylobacterium zucineum HLK1  Bacteria
# 25                      Cellulomonas flavigena DSM 20109  Bacteria
# 26                      Chloroflexus aurantiacus J-10-fl  Bacteria
# 27                           Pseudomonas entomophila L48  Bacteria
# 28                        Neisseria lactamica ATCC 23970  Bacteria
# 29                           Methylocella silvestris BL2  Bacteria
# ...                                                  ...       ...
# 32378             Syntrophothermus lipocalidus DSM 12680  Bacteria
# 32379          Acidithiobacillus ferrooxidans ATCC 53993  Bacteria
# 32380            Hyphomicrobium denitrificans ATCC 51888  Bacteria
# 32381                 Methanosarcina barkeri str. Fusaro   Archaea
# 32382                               Geobacter lovleyi SZ  Bacteria
# 32383                      Methanocella paludicola SANAE   Archaea
# 32384                          Kyrpidia tusciae DSM 2912  Bacteria
# 32385                 Methanohalobium evestigatum Z-7303   Archaea
# 32386                       Methanocella arvoryzae MRE50   Archaea
# 32387                         Methanopyrus kandleri AV19   Archaea
# 32388  Desulfovibrio desulfuricans subsp. desulfurica...  Bacteria
# 32389                         Thioalkalivibrio sp. ALJ17  Bacteria
# 32390                              Thermincola potens JR  Bacteria
# 32391                               Aquifex aeolicus VF5  Bacteria
# 32392                  Heliobacterium modesticaldum Ice1  Bacteria
# 32393                    Thermomicrobium roseum DSM 5159  Bacteria
# 32394                     Ilyobacter polytropus DSM 2926  Bacteria
# 32395  Methanothermobacter thermautotrophicus str. De...   Archaea
# 32396                   Methanohalophilus mahii DSM 5219   Archaea
# 32397               Desulfotomaculum acetoxidans DSM 771  Bacteria
# 32398                    Archaeoglobus fulgidus DSM 4304   Archaea
# 32399                         Methanococcus vannielii SB   Archaea
# 32400              Methanobrevibacter smithii ATCC 35061   Archaea
# 32401               Slackia heliotrinireducens DSM 20476  Bacteria
# 32402                   Archaeoglobus profundus DSM 5631   Archaea
# 32403                Desulfobacterium autotrophicum HRM2  Bacteria
# 32404              Thiobacillus denitrificans ATCC 25259  Bacteria
# 32405           Carboxydothermus hydrogenoformans Z-2901  Bacteria
# 32406                 Methanosarcina barkeri str. Fusaro   Archaea
# 32407                            Cyanothece sp. PCC 7424  Bacteria
#
#              ...         WestPond_TuleC_D1 WestPond_TuleC_D2 White_CordA_D2  \
# 0            ...                      29.0              20.0            3.0
# 1            ...                       4.0               2.0            2.0
# 2            ...                      37.0              27.0            4.0
# 3            ...                       1.0               1.0            4.0
# 4            ...                       1.0               2.0            1.0
# 5            ...                       2.0               2.0            0.0
# 6            ...                       0.0               1.0            0.0
# 7            ...                       8.0               6.0            0.0
# 8            ...                      25.0              27.0            1.0
# 9            ...                       3.0               2.0            5.0
# 10           ...                       0.0               1.0            0.0
# 11           ...                       2.0               3.0           47.0
# 12           ...                      96.0              69.0           25.0
# 13           ...                       6.0              12.0            1.0
# 14           ...                      63.0              59.0           67.0
# 15           ...                       9.0               7.0            1.0
# 16           ...                       0.0               1.0            1.0
# 17           ...                       4.0               2.0            0.0
# 18           ...                       8.0               4.0            0.0
# 19           ...                       1.0               1.0            0.0
# 20           ...                       1.0               3.0            1.0
# 21           ...                       2.0               1.0            0.0
# 22           ...                      96.0             105.0           22.0
# 23           ...                      60.0              87.0           31.0
# 24           ...                       8.0               9.0            0.0
# 25           ...                       9.0              15.0            1.0
# 26           ...                      16.0              18.0            5.0
# 27           ...                       0.0               2.0            1.0
# 28           ...                       5.0               4.0            1.0
# 29           ...                      39.0              27.0            1.0
# ...          ...                       ...               ...            ...
# 32378        ...                       3.0              11.0            0.0
# 32379        ...                       5.0              15.0          165.0
# 32380        ...                      11.0              13.0          100.0
# 32381        ...                       1.0               4.0            0.0
# 32382        ...                       3.0               2.0            2.0
# 32383        ...                       0.0               0.0            0.0
# 32384        ...                       0.0               2.0            1.0
# 32385        ...                       0.0               0.0            0.0
# 32386        ...                       0.0               0.0            0.0
# 32387        ...                       1.0               1.0            5.0
# 32388        ...                       6.0               7.0           12.0
# 32389        ...                       4.0              12.0           38.0
# 32390        ...                       0.0               3.0            0.0
# 32391        ...                       0.0               0.0            0.0
# 32392        ...                       0.0               0.0            1.0
# 32393        ...                       2.0               1.0            1.0
# 32394        ...                       3.0               3.0            6.0
# 32395        ...                       0.0               5.0            0.0
# 32396        ...                       0.0               2.0            0.0
# 32397        ...                       0.0               1.0            0.0
# 32398        ...                      27.0              37.0          224.0
# 32399        ...                       2.0               0.0            1.0
# 32400        ...                       0.0               1.0            0.0
# 32401        ...                       7.0               1.0            5.0
# 32402        ...                       2.0              10.0            0.0
# 32403        ...                       6.0              13.0           78.0
# 32404        ...                      79.0             104.0          122.0
# 32405        ...                       7.0               6.0            6.0
# 32406        ...                       7.0               9.0            1.0
# 32407        ...                       0.0               0.0            5.0
#
#       White_CordB_D2 White_ThreeSqA_D1 White_ThreeSqA_D2  White_ThreeSqB_D1  \
# 0                5.0              10.0              12.0                8.0
# 1                9.0              14.0               8.0               10.0
# 2                1.0               9.0              13.0               13.0
# 3                0.0               4.0               7.0                6.0
# 4                3.0               1.0               2.0                1.0
# 5                0.0               0.0               0.0                0.0
# 6                1.0               0.0               0.0                0.0
# 7                1.0               5.0               7.0                2.0
# 8                2.0               9.0              12.0               10.0
# 9                3.0               8.0               4.0                3.0
# 10               0.0               0.0               1.0                0.0
# 11              17.0              17.0              31.0               36.0
# 12              12.0              29.0              40.0               42.0
# 13               2.0               1.0               1.0                0.0
# 14              47.0              90.0              81.0               75.0
# 15               2.0               0.0               0.0                1.0
# 16               0.0               1.0               1.0                0.0
# 17               1.0               0.0               0.0                0.0
# 18               1.0               1.0               0.0                0.0
# 19               0.0               0.0               0.0                1.0
# 20               1.0               1.0               1.0                0.0
# 21               2.0               2.0               2.0                4.0
# 22              12.0              42.0              50.0               45.0
# 23              36.0              20.0               6.0                9.0
# 24               1.0               0.0               2.0                3.0
# 25               1.0               0.0               0.0                1.0
# 26               2.0              12.0              16.0               15.0
# 27               2.0               3.0               4.0                2.0
# 28               0.0               3.0               2.0                0.0
# 29               2.0               6.0               9.0                5.0
# ...              ...               ...               ...                ...
# 32378            0.0               0.0               0.0                0.0
# 32379           65.0              97.0             127.0              115.0
# 32380           68.0              66.0             107.0               74.0
# 32381            0.0               0.0               0.0                0.0
# 32382            0.0               0.0               2.0                0.0
# 32383            0.0               0.0               0.0                0.0
# 32384            0.0               6.0              13.0                3.0
# 32385            0.0               0.0               0.0                0.0
# 32386            0.0               0.0               0.0                0.0
# 32387            5.0               0.0               0.0                0.0
# 32388           13.0               2.0               3.0                2.0
# 32389           39.0              37.0              78.0               56.0
# 32390            0.0               0.0               1.0                0.0
# 32391            0.0               2.0               0.0                1.0
# 32392            1.0               0.0               0.0                0.0
# 32393            0.0              13.0              10.0                9.0
# 32394            5.0               2.0               2.0                0.0
# 32395            0.0               0.0               0.0                0.0
# 32396            0.0               0.0               0.0                0.0
# 32397            0.0               0.0               0.0                1.0
# 32398          134.0              58.0             118.0               85.0
# 32399            0.0               0.0               0.0                0.0
# 32400            2.0               0.0               0.0                0.0
# 32401           14.0               4.0               2.0                4.0
# 32402            3.0               2.0               0.0                0.0
# 32403           57.0              25.0              31.0               30.0
# 32404           49.0              50.0              34.0               28.0
# 32405           10.0               1.0               0.0                6.0
# 32406            2.0               0.0               1.0                0.0
# 32407            2.0               0.0               1.0                0.0
#
#        White_ThreeSqB_D2  White_ThreeSqC_D1  White_ThreeSqC_D2
# 0                    3.0                8.0                6.0
# 1                   11.0               10.0                6.0
# 2                    6.0                4.0               10.0
# 3                    5.0                9.0                6.0
# 4                    0.0                1.0                3.0
# 5                    0.0                1.0                0.0
# 6                    0.0                0.0                0.0
# 7                    1.0                1.0                0.0
# 8                   12.0               10.0               14.0
# 9                    6.0                6.0                6.0
# 10                   0.0                0.0                0.0
# 11                  19.0               19.0               16.0
# 12                  15.0               13.0               22.0
# 13                   0.0                5.0                0.0
# 14                 103.0               52.0               69.0
# 15                   0.0                2.0                0.0
# 16                   0.0                0.0                0.0
# 17                   0.0                1.0                0.0
# 18                   2.0                2.0                2.0
# 19                   1.0                0.0                1.0
# 20                   0.0                0.0                0.0
# 21                   6.0                4.0                9.0
# 22                  26.0               13.0               36.0
# 23                  32.0               26.0               14.0
# 24                   6.0                3.0                4.0
# 25                   2.0                0.0                0.0
# 26                  19.0               13.0                8.0
# 27                   6.0                6.0               13.0
# 28                   3.0                1.0                2.0
# 29                   4.0                3.0                5.0
# ...                  ...                ...                ...
# 32378                0.0                0.0                0.0
# 32379               59.0               53.0               62.0
# 32380               42.0               46.0               51.0
# 32381                1.0                0.0                0.0
# 32382                1.0                0.0                0.0
# 32383                0.0                0.0                0.0
# 32384                6.0                4.0                8.0
# 32385                0.0                0.0                0.0
# 32386                0.0                0.0                0.0
# 32387                1.0                2.0                2.0
# 32388                6.0               11.0                7.0
# 32389               29.0               30.0               33.0
# 32390                0.0                0.0                1.0
# 32391                3.0                0.0                4.0
# 32392                0.0                1.0                0.0
# 32393                4.0                3.0                3.0
# 32394                4.0                4.0                2.0
# 32395                1.0                0.0                1.0
# 32396                0.0                0.0                0.0
# 32397                2.0                2.0                2.0
# 32398              176.0              148.0              132.0
# 32399                1.0                0.0                0.0
# 32400                0.0                0.0                0.0
# 32401                6.0                4.0                3.0
# 32402                2.0                2.0                0.0
# 32403               80.0               56.0               62.0
# 32404               98.0               41.0               55.0
# 32405               14.0                7.0                6.0
# 32406                5.0                1.0                0.0
# 32407                2.0                1.0                0.0
#
# [32408 rows x 149 columns]

# %%
## Not a terrible amount of duplication now. 32k vs. 31k

# %% [markdown]
# ## Write table Out

# %%
KOsubset_md5Tax_counts133.to_csv("KOsubset_md5Tax_counts133.txt", sep ='\t')

# %%
# Look at some tables for taxonomy

# %%
# Look at only K00399
KOmd5_TaxCounts = KOsubset_md5Tax_counts133  # shorten

mcrA = KOmd5_TaxCounts[KOmd5_TaxCounts.KO=="K00399"]
#mcrA.iloc[:,:15]
#mcrA = KOmd5_TaxCounts[KOmd5_TaxCounts.KO==]
#mcrA2 = KOmd5_TaxCounts[KOmd5_TaxCounts.KO=="K00400"]
mcrA
# mcrABG['K00399','K00400']
pta= KOmd5_TaxCounts[KOmd5_TaxCounts.KO=="K00625"] # phosphate acetyltransferase
pta
# Out:
#                 L1          L3      KO           gene  \
# 28961  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28962  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28963  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28964  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28965  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28966  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28967  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28968  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28969  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28970  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28971  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28972  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28973  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28974  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28975  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28976  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28977  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28978  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28979  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28980  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28981  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28982  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28983  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28984  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28985  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28986  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28987  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28988  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28989  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 28990  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# ...            ...         ...     ...            ...
# 29278  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29279  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29280  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29281  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29282  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29283  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29284  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29285  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29286  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29287  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29288  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29289  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29290  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29291  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29292  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29293  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29294  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29295  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29296  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29297  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29298  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29299  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29300  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29301  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29302  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29303  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29304  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29305  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29306  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
# 29307  CH4_cycling  CH4_Acetat  K00625  E2.3.1.8, pta
#
#                           function            EC  \
# 28961  phosphate acetyltransferase  [EC:2.3.1.8]
# 28962  phosphate acetyltransferase  [EC:2.3.1.8]
# 28963  phosphate acetyltransferase  [EC:2.3.1.8]
# 28964  phosphate acetyltransferase  [EC:2.3.1.8]
# 28965  phosphate acetyltransferase  [EC:2.3.1.8]
# 28966  phosphate acetyltransferase  [EC:2.3.1.8]
# 28967  phosphate acetyltransferase  [EC:2.3.1.8]
# 28968  phosphate acetyltransferase  [EC:2.3.1.8]
# 28969  phosphate acetyltransferase  [EC:2.3.1.8]
# 28970  phosphate acetyltransferase  [EC:2.3.1.8]
# 28971  phosphate acetyltransferase  [EC:2.3.1.8]
# 28972  phosphate acetyltransferase  [EC:2.3.1.8]
# 28973  phosphate acetyltransferase  [EC:2.3.1.8]
# 28974  phosphate acetyltransferase  [EC:2.3.1.8]
# 28975  phosphate acetyltransferase  [EC:2.3.1.8]
# 28976  phosphate acetyltransferase  [EC:2.3.1.8]
# 28977  phosphate acetyltransferase  [EC:2.3.1.8]
# 28978  phosphate acetyltransferase  [EC:2.3.1.8]
# 28979  phosphate acetyltransferase  [EC:2.3.1.8]
# 28980  phosphate acetyltransferase  [EC:2.3.1.8]
# 28981  phosphate acetyltransferase  [EC:2.3.1.8]
# 28982  phosphate acetyltransferase  [EC:2.3.1.8]
# 28983  phosphate acetyltransferase  [EC:2.3.1.8]
# 28984  phosphate acetyltransferase  [EC:2.3.1.8]
# 28985  phosphate acetyltransferase  [EC:2.3.1.8]
# 28986  phosphate acetyltransferase  [EC:2.3.1.8]
# 28987  phosphate acetyltransferase  [EC:2.3.1.8]
# 28988  phosphate acetyltransferase  [EC:2.3.1.8]
# 28989  phosphate acetyltransferase  [EC:2.3.1.8]
# 28990  phosphate acetyltransferase  [EC:2.3.1.8]
# ...                            ...           ...
# 29278  phosphate acetyltransferase  [EC:2.3.1.8]
# 29279  phosphate acetyltransferase  [EC:2.3.1.8]
# 29280  phosphate acetyltransferase  [EC:2.3.1.8]
# 29281  phosphate acetyltransferase  [EC:2.3.1.8]
# 29282  phosphate acetyltransferase  [EC:2.3.1.8]
# 29283  phosphate acetyltransferase  [EC:2.3.1.8]
# 29284  phosphate acetyltransferase  [EC:2.3.1.8]
# 29285  phosphate acetyltransferase  [EC:2.3.1.8]
# 29286  phosphate acetyltransferase  [EC:2.3.1.8]
# 29287  phosphate acetyltransferase  [EC:2.3.1.8]
# 29288  phosphate acetyltransferase  [EC:2.3.1.8]
# 29289  phosphate acetyltransferase  [EC:2.3.1.8]
# 29290  phosphate acetyltransferase  [EC:2.3.1.8]
# 29291  phosphate acetyltransferase  [EC:2.3.1.8]
# 29292  phosphate acetyltransferase  [EC:2.3.1.8]
# 29293  phosphate acetyltransferase  [EC:2.3.1.8]
# 29294  phosphate acetyltransferase  [EC:2.3.1.8]
# 29295  phosphate acetyltransferase  [EC:2.3.1.8]
# 29296  phosphate acetyltransferase  [EC:2.3.1.8]
# 29297  phosphate acetyltransferase  [EC:2.3.1.8]
# 29298  phosphate acetyltransferase  [EC:2.3.1.8]
# 29299  phosphate acetyltransferase  [EC:2.3.1.8]
# ...                                                  ...       ...
# 29278               Legionella pneumophila 2300/99 Alcoy  Bacteria
# 29279                         Listeria innocua Clip11262  Bacteria
# 29280                 Methylobacterium nodulans ORS 2060  Bacteria
# 29281                   Lactobacillus fermentum IFO 3956  Bacteria
# 29282                    Burkholderia pseudomallei 1026a  Bacteria
# 29283                     Burkholderia thailandensis Bt4  Bacteria
# 29284                             Streptococcus mitis B6  Bacteria
# 29285                         Rickettsia felis URRWXCal2  Bacteria
# 29286                    Oceanobacillus iheyensis HTE831  Bacteria
# 29287                              Azospirillum sp. B510  Bacteria
# 29288                          Ralstonia eutropha JMP134  Bacteria
# 29289                         Mycoplasma hyorhinis HUB-1  Bacteria
# 29290            Hyphomicrobium denitrificans ATCC 51888  Bacteria
# 29291                     Cupriavidus metallidurans CH34  Bacteria
# 29292                     Lactobacillus johnsonii FI9785  Bacteria
# 29293                Burkholderia multivorans ATCC 17616  Bacteria
# 29294                    Methylobacterium extorquens AM1  Bacteria
# 29295                         Lactobacillus casei A2-362  Bacteria
# 29296                       Sinorhizobium medicae WSM419  Bacteria
# 29297                               Borrelia garinii PBi  Bacteria
# 29298                  Rhodopseudomonas palustris CGA009  Bacteria
# 29299                               Ruminococcus albus 7  Bacteria
# 29300                          Ralstonia eutropha JMP134  Bacteria
# 29301                   Paludibacter propionicigenes WB4  Bacteria
# 29302                Denitrovibrio acetiphilus DSM 12809  Bacteria
# 29303                   Sebaldella termitidis ATCC 33386  Bacteria
# 29304                     Clostridium cellulovorans 743B  Bacteria
# 29305                     Methanosarcina acetivorans C2A   Archaea
# 29306                   Pelobacter carbinolicus DSM 2380  Bacteria
# 29307                   Streptococcus pyogenes BJCYGAS15  Bacteria
#
#              ...         WestPond_TuleC_D1 WestPond_TuleC_D2 White_CordA_D2  \
# 28961        ...                      42.0              32.0            8.0
# 28962        ...                       0.0               0.0            0.0
# 28963        ...                       6.0               2.0            3.0
# 28964        ...                       0.0               0.0            1.0
# 28965        ...                       0.0               0.0            2.0
# 28966        ...                       0.0               2.0            0.0
# 28967        ...                      34.0              62.0           16.0
# 28968        ...                       3.0               0.0            3.0
# 28969        ...                       5.0               6.0            3.0
# 28970        ...                      20.0              27.0           11.0
# 28971        ...                      31.0              36.0           11.0
# 28972        ...                       0.0               1.0            4.0
# 28973        ...                       1.0               2.0            1.0
# 28974        ...                       3.0               1.0            5.0
# 28975        ...                       1.0               3.0            1.0
# 28976        ...                       0.0               0.0            1.0
# 28977        ...                       1.0               3.0            0.0
# 28978        ...                       0.0               0.0            0.0
# 28979        ...                       0.0               0.0            1.0
# 28980        ...                       0.0               0.0            0.0
# 28981        ...                      10.0               7.0            0.0
# 28982        ...                       0.0               3.0            5.0
# 28983        ...                       0.0               0.0            0.0
# 28984        ...                      28.0              27.0           25.0
# 28985        ...                       1.0               2.0            2.0
# 28986        ...                       0.0               0.0            0.0
# 28987        ...                       0.0               0.0            3.0
# 28988        ...                      14.0               8.0            4.0
# 28989        ...                       2.0               3.0            2.0
# 28990        ...                       1.0               2.0            3.0
# ...          ...                       ...               ...            ...
# 29278        ...                       1.0               2.0            0.0
# 29279        ...                       0.0               0.0            1.0
# 29280        ...                      10.0              16.0           14.0
# 29281        ...                       3.0               1.0            0.0
# 29282        ...                      12.0               8.0            4.0
# 29283        ...                       3.0               3.0            1.0
# 29284        ...                       0.0               0.0            0.0
# 29285        ...                       4.0               0.0            0.0
# 29286        ...                       0.0               3.0            4.0
# 29287        ...                      12.0               9.0           20.0
# 29288        ...                       9.0              10.0            0.0
# 29289        ...                       1.0               0.0            0.0
# 29290        ...                       9.0              11.0            6.0
# 29291        ...                      24.0              34.0           16.0
# 29292        ...                       0.0               0.0            0.0
# 29293        ...                       2.0               3.0            0.0
# 29294        ...                       1.0               2.0            3.0
# 29295        ...                       0.0               1.0            0.0
# 29296        ...                      21.0              43.0            8.0
# 29297        ...                       0.0               1.0            0.0
# 29298        ...                      20.0              24.0           13.0
# 29299        ...                       1.0               1.0            0.0
# 29300        ...                      30.0              39.0           15.0
# 29301        ...                      22.0              16.0           16.0
# 29302        ...                       4.0              10.0           10.0
# 29303        ...                       7.0               5.0            2.0
# 29304        ...                       1.0               3.0            5.0
# 29305        ...                       3.0               0.0            0.0
# 29306        ...                      22.0              17.0           90.0
# 29307        ...                       0.0               0.0            0.0
#
#       White_CordB_D2 White_ThreeSqA_D1 White_ThreeSqA_D2  White_ThreeSqB_D1  \
# 28961            6.0              15.0              12.0                9.0
# 28962            0.0               0.0               0.0                0.0
# 28963            1.0               8.0               5.0                5.0
# 28964            0.0               2.0               1.0                0.0
# 28965            2.0               1.0               0.0                2.0
# 28966            2.0               0.0               1.0                0.0
# 28967           11.0               8.0               8.0                6.0
# 28968            2.0               1.0               3.0                1.0
# 28969            5.0              10.0               9.0               15.0
# 28970           10.0               7.0              19.0               10.0
# 28971            5.0               3.0               2.0                1.0
# 28972            0.0               2.0               1.0                0.0
# 28973            0.0               1.0               1.0                1.0
# 28974            3.0               1.0               0.0                2.0
# 28975            3.0               3.0               6.0                2.0
# 28976            1.0               0.0               1.0                0.0
# 28977            1.0               0.0               1.0                0.0
# 28978            0.0               0.0               0.0                0.0
# 28979            1.0               2.0               0.0                0.0
# 28980            0.0               1.0               1.0                0.0
# 28981            0.0               0.0               0.0                0.0
# 28982            1.0               2.0               5.0                3.0
# 28983            1.0               0.0               0.0                0.0
# 28984           14.0              12.0              23.0               18.0
# 28985            2.0               1.0               0.0                0.0
# 28986            0.0               0.0               0.0                0.0
# 28987            3.0               0.0               1.0                0.0
# 28988            4.0               2.0               8.0                6.0
# 28989            0.0               1.0               0.0                0.0
# 28990            5.0               3.0               2.0                3.0
# ...              ...               ...               ...                ...
# 29278            0.0               0.0               0.0                0.0
# 29279            0.0               0.0               1.0                0.0
# 29280           15.0               4.0               7.0                8.0
# 29281            0.0               2.0               0.0                0.0
# 29282            5.0               3.0               0.0                1.0
# 29283            2.0               1.0               3.0                0.0
# 29284            0.0               0.0               0.0                0.0
# 29285            0.0               1.0               0.0                2.0
# 29286            0.0               2.0               3.0                5.0
